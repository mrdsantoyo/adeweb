# %%
import pandas as pd
import datetime as dt

workbook = pd.ExcelFile("//192.168.10.2/Compartidos/Calidad Compartida (192.168.10.254)/5. KPI´s calidad/2025/Reporte de POES 2025.xlsx")
df = pd.read_excel(
                    io=workbook,
                    sheet_name='%diario',
                    usecols='A:NB',
                    skiprows=6,
                    nrows=30,
                    header=0
                    )

fecha_inicio = dt.date(2025, 1, 1)
num_dias = df.columns.size - 1

date_labels = [
    (fecha_inicio + dt.timedelta(days=i)).strftime('%d/%m/%y') 
    for i in range(num_dias)
    ]

df.columns = ["Área"] + date_labels
df.reset_index(drop=True)
df = df.T
df.columns = df.iloc[0]
df = df.iloc[1:]
df = df.apply(pd.to_numeric, errors='coerce')
df.index = pd.to_datetime(df.index, format='%d/%m/%y')

df
# Out:
# Área        Ahumados   Corte  Empaque 1  Empaque 2  Envasado   Frita   \
# 2025-01-01       NaN     NaN        NaN        NaN        NaN     NaN
# 2025-01-02       NaN   96.07        NaN      100.0      100.0  100.00
# 2025-01-03       NaN  100.00        NaN      100.0      100.0   98.48
# 2025-01-04       NaN     NaN        NaN      100.0        NaN     NaN
# 2025-01-05       NaN     NaN        NaN        NaN        NaN     NaN
# ...              ...     ...        ...        ...        ...     ...
# 2025-12-27       NaN     NaN        NaN        NaN        NaN     NaN
# 2025-12-28       NaN     NaN        NaN        NaN        NaN     NaN
# 2025-12-29       NaN     NaN        NaN        NaN        NaN     NaN
# 2025-12-30       NaN     NaN        NaN        NaN        NaN     NaN
# 2025-12-31       NaN     NaN        NaN        NaN        NaN     NaN
#
# Área        Habilitamiento   Inyección   Pellet  Deshuese  ...  Pasillos  \
# 2025-01-01              NaN         NaN     NaN       NaN  ...       NaN
# 2025-01-02             98.0         NaN   100.0     100.0  ...    100.00
# 2025-01-03             98.0       100.0   100.0     100.0  ...     95.34
# 2025-01-04              NaN         NaN     NaN     100.0  ...       NaN
# 2025-01-05              NaN         NaN     NaN       NaN  ...       NaN
# ...                     ...         ...     ...       ...  ...       ...
# 2025-12-27              NaN         NaN     NaN       NaN  ...       NaN
# 2025-12-28              NaN         NaN     NaN       NaN  ...       NaN
# 2025-12-29              NaN         NaN     NaN       NaN  ...       NaN
# 2025-12-30              NaN         NaN     NaN       NaN  ...       NaN
# 2025-12-31              NaN         NaN     NaN       NaN  ...       NaN
#
# Área        Refrigeración y Congelación   Condimentos  Camaras de agudos  \
# 2025-01-01                           NaN          NaN                NaN
# 2025-01-02                        100.00        100.0             100.00
# 2025-01-03                        100.00        100.0             100.00
# 2025-01-04                         95.38          NaN              96.77
# 2025-01-05                           NaN          NaN                NaN
# ...                                  ...          ...                ...
# 2025-12-27                           NaN          NaN                NaN
# 2025-12-28                           NaN          NaN                NaN
# 2025-12-29                           NaN          NaN                NaN
# 2025-12-30                           NaN          NaN                NaN
# 2025-12-31                           NaN          NaN                NaN
#
# Área        Lavado de Cajas y Cuarto de Químicos  Almacen de Secos  Empaque 3  \
# 2025-01-01                                   NaN               NaN        NaN
# 2025-01-02                                 100.0             100.0        NaN
# 2025-01-03                                 100.0             100.0        NaN
# 2025-01-04                                   NaN             100.0        NaN
# 2025-01-05                                   NaN               NaN        NaN
# ...                                          ...               ...        ...
# 2025-12-27                                   NaN               NaN        NaN
# 2025-12-28                                   NaN               NaN        NaN
# 2025-12-29                                   NaN               NaN        NaN
# 2025-12-30                                   NaN               NaN        NaN
# 2025-12-31                                   NaN               NaN        NaN
#
# Área        Marinados  Empaque 4  Cocidos y esterilizados
# 2025-01-01        NaN        NaN                       NaN
# 2025-01-02        NaN      100.0                      96.6
# 2025-01-03      100.0      100.0                     100.0
# 2025-01-04        NaN      100.0                       NaN
# 2025-01-05        NaN        NaN                       NaN
# ...               ...        ...                       ...
# 2025-12-27        NaN        NaN                       NaN
# 2025-12-28        NaN        NaN                       NaN
# 2025-12-29        NaN        NaN                       NaN
# 2025-12-30        NaN        NaN                       NaN
# 2025-12-31        NaN        NaN                       NaN
#
# [365 rows x 21 columns]
